# %%
import os
print(os.environ.get("JAVA_HOME"))
# !java -version
# Out:
# None
# openjdk version "17.0.16" 2025-07-15
# OpenJDK Runtime Environment (build 17.0.16+8-Ubuntu-0ubuntu122.04.1)
# OpenJDK 64-Bit Server VM (build 17.0.16+8-Ubuntu-0ubuntu122.04.1, mixed mode, sharing)

# %%
# !ls /usr/lib/jvm
# Out:
# java-1.17.0-openjdk-amd64  java-17-openjdk-amd64

# %%
# ---- Find Java, set JAVA_HOME, install PySpark, start Spark ----
import os, shutil, pathlib, subprocess

# 1) Locate the actual java binary (works on Linux/macOS, Anaconda, etc.)
java_bin = shutil.which("java")
if not java_bin:
    raise RuntimeError("Java not found on PATH. Install JDK 11–21 first.")

java_real = os.path.realpath(java_bin)                 # resolve symlinks
JAVA_HOME = str(pathlib.Path(java_real).parent.parent) # .../bin/java -> go up 2
os.environ["JAVA_HOME"] = JAVA_HOME
os.environ["PATH"] = f"{JAVA_HOME}/bin:" + os.environ["PATH"]

print("JAVA_HOME ->", os.environ["JAVA_HOME"])
subprocess.run(["java", "-version"], check=False)

# 2) Ensure PySpark is available
import sys
# !{sys.executable} -m pip install -q pyspark

# 3) Start Spark
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("FAA_NOAA_Integration")
    .master("local[*]")
    .config("spark.driver.memory", "2g")
    .config("spark.executor.memory", "2g")
    .config("spark.driver.extraJavaOptions", "-Xss4M")
    .config("spark.executor.extraJavaOptions", "-Xss4M")
    .getOrCreate()
)

spark
# Out:
# JAVA_HOME -> /usr/lib/jvm/java-17-openjdk-amd64
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://df7329206806:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>FAA_NOAA_Integration</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.1)

# %% [markdown]
# ### Creating a `.env` file
#
# A `.env` file typically contains key-value pairs, where each line defines an environment variable. For example, if you have an API key, you would add a line like `NOAA_TOKEN="your_noaa_api_key_here"`.

# %%
# %%writefile .env
# NOAA_TOKEN="UYWGZCnhVtUKAGHQFkpTPRrxAanxYmMA"
# Out:
# Writing .env

# %%
# !cat .env
# Out:
# NOAA_TOKEN="UYWGZCnhVtUKAGHQFkpTPRrxAanxYmMA"

# %% [markdown]
# Remember to replace `"YOUR_ACTUAL_NOAA_API_KEY"` with your actual NOAA API token. After creating the file, you can load these variables into your Python environment using libraries like `python-dotenv`, as you've already demonstrated in your notebook.

# %%
from dotenv import load_dotenv
import os

load_dotenv()
NOAA_TOKEN = os.getenv("NOAA_TOKEN")

if NOAA_TOKEN:
    print("NOAA token loaded successfully!")
else:
    print("NOAA token not found.")
# Out:
# NOAA token loaded successfully!

# %%
airport_to_station = {
    "ATL": "GHCND:USW00013874",
    "DFW": "GHCND:USW00003927",
    "DEN": "GHCND:USW00003017",
    "ORD": "GHCND:USW00094846",
    "LAX": "GHCND:USW00093134",
    "CLT": "GHCND:USW00013881",
    "LAS": "GHCND:USW00023169",
    "MCO": "GHCND:USW00012815",
    "PHX": "GHCND:USW00023183",
    "MIA": "GHCND:USW00012839",
    "SEA": "GHCND:USW00024233",
    "EWR": "GHCND:USW00014734",
    "JFK": "GHCND:USW00094789",
    "SFO": "GHCND:USW00023234",
    "BOS": "GHCND:USW00014739"
}

# %%
import requests
import pandas as pd

def fetch_noaa_weather(station_id, start_date, end_date, token):
    """
    Fetch daily weather data from NOAA GHCND dataset for a given station and date range.

    Returns a clean pivoted DataFrame with columns like TMAX, TMIN, PRCP.

    Args:
        station_id (str): NOAA station ID (e.g., "GHCND:USW00094728")
        start_date (str): Start date in 'YYYY-MM-DD' format
        end_date (str): End date in 'YYYY-MM-DD' format
        token (str): NOAA API token
    """
    url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data"
    headers = {"token": token}
    limit = 1000
    offset = 1
    all_data = []

    while True:
        params = {
            "datasetid": "GHCND",
            "stationid": station_id,
            "startdate": start_date,
            "enddate": end_date,
            "limit": limit,
            "offset": offset,
            "units": "standard"
        }

        response = requests.get(url, headers=headers, params=params)
        if response.status_code != 200:
            print(f"Error {response.status_code}: {response.text}")
            break

        results = response.json().get("results", [])
        if not results:
            break

        all_data.extend(results)
        offset += limit

    if not all_data:
        return pd.DataFrame()  # Return empty if no data

    df = pd.DataFrame(all_data)

    df['date'] = pd.to_datetime(df['date'])
    df['value'] = pd.to_numeric(df['value'], errors='coerce')

    df_pivot = df.pivot_table(index='date', columns='datatype', values='value').reset_index()

    return df_pivot

# %%
import pandas as pd
import time

def fetch_station_monthly(station_id, start_date, end_date, token):
    start = pd.to_datetime(start_date)
    end = pd.to_datetime(end_date)

    all_chunks = []
    current = start

    while current < end:
        # Set next month boundary
        next_month = (current.replace(day=1) + pd.DateOffset(months=1))
        chunk_start = current.strftime("%Y-%m-%d")
        chunk_end = min(next_month, end).strftime("%Y-%m-%d")

        print(f"   → Fetching {station_id} | {chunk_start} to {chunk_end}")

        try:
            df_chunk = fetch_noaa_weather(
                station_id=station_id,
                start_date=chunk_start,
                end_date=chunk_end,
                token=token
            )
            if not df_chunk.empty:
                all_chunks.append(df_chunk)

        except Exception as e:
            print("      ⚠️ Error:", e)

        # Avoid 429 rate limit
        time.sleep(0.4)

        current = next_month

    if all_chunks:
        return pd.concat(all_chunks, ignore_index=True)
    return pd.DataFrame()

# %%
START_DATE = "2015-01-01"
END_DATE   = "2025-01-01"   # stop point

all_weather = []

for airport, station in airport_to_station.items():
    print(f"\n📡 Fetching weather for {airport} ({station})")

    df = fetch_station_monthly(
        station_id=station,
        start_date=START_DATE,
        end_date=END_DATE,
        token=NOAA_TOKEN
    )

    if df.empty:
        print(f"   ❌ No data for {airport}")
        continue

    df["airport"] = airport
    df["station_id"] = station

    all_weather.append(df)
    print(f"   ✅ Completed {airport}: {df.shape[0]} rows")
# Out:
# 📡 Fetching weather for ATL (GHCND:USW00013874)
#    → Fetching GHCND:USW00013874 | 2015-01-01 to 2015-02-01
#    → Fetching GHCND:USW00013874 | 2015-02-01 to 2015-03-01
#    → Fetching GHCND:USW00013874 | 2015-03-01 to 2015-04-01
#    → Fetching GHCND:USW00013874 | 2015-04-01 to 2015-05-01
#    → Fetching GHCND:USW00013874 | 2015-05-01 to 2015-06-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00013874 | 2015-06-01 to 2015-07-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00013874 | 2015-07-01 to 2015-08-01
#    → Fetching GHCND:USW00013874 | 2015-08-01 to 2015-09-01
#    → Fetching GHCND:USW00013874 | 2015-09-01 to 2015-10-01
#    → Fetching GHCND:USW00013874 | 2015-10-01 to 2015-11-01
#    → Fetching GHCND:USW00013874 | 2015-11-01 to 2015-12-01
#    → Fetching GHCND:USW00013874 | 2015-12-01 to 2016-01-01
#    → Fetching GHCND:USW00013874 | 2016-01-01 to 2016-02-01
#    → Fetching GHCND:USW00013874 | 2016-02-01 to 2016-03-01
#    → Fetching GHCND:USW00013874 | 2016-03-01 to 2016-04-01
#    → Fetching GHCND:USW00013874 | 2016-04-01 to 2016-05-01
#    → Fetching GHCND:USW00013874 | 2016-05-01 to 2016-06-01
#    → Fetching GHCND:USW00013874 | 2016-06-01 to 2016-07-01
#    → Fetching GHCND:USW00013874 | 2016-07-01 to 2016-08-01
#    → Fetching GHCND:USW00013874 | 2016-08-01 to 2016-09-01
#    → Fetching GHCND:USW00013874 | 2016-09-01 to 2016-10-01
#    → Fetching GHCND:USW00013874 | 2016-10-01 to 2016-11-01
#    → Fetching GHCND:USW00013874 | 2016-11-01 to 2016-12-01
#    → Fetching GHCND:USW00013874 | 2016-12-01 to 2017-01-01
#    → Fetching GHCND:USW00013874 | 2017-01-01 to 2017-02-01
#    → Fetching GHCND:USW00013874 | 2017-02-01 to 2017-03-01
#    → Fetching GHCND:USW00013874 | 2017-03-01 to 2017-04-01
#    → Fetching GHCND:USW00013874 | 2017-04-01 to 2017-05-01
#    → Fetching GHCND:USW00013874 | 2017-05-01 to 2017-06-01
#    → Fetching GHCND:USW00013874 | 2017-06-01 to 2017-07-01
#    → Fetching GHCND:USW00013874 | 2017-07-01 to 2017-08-01
#    → Fetching GHCND:USW00013874 | 2017-08-01 to 2017-09-01
#    → Fetching GHCND:USW00013874 | 2017-09-01 to 2017-10-01
#    → Fetching GHCND:USW00013874 | 2017-10-01 to 2017-11-01
#    → Fetching GHCND:USW00013874 | 2017-11-01 to 2017-12-01
#    → Fetching GHCND:USW00013874 | 2017-12-01 to 2018-01-01
#    → Fetching GHCND:USW00013874 | 2018-01-01 to 2018-02-01
#    → Fetching GHCND:USW00013874 | 2018-02-01 to 2018-03-01
#    → Fetching GHCND:USW00013874 | 2018-03-01 to 2018-04-01
#    → Fetching GHCND:USW00013874 | 2018-04-01 to 2018-05-01
#    → Fetching GHCND:USW00013874 | 2018-05-01 to 2018-06-01
#    → Fetching GHCND:USW00013874 | 2018-06-01 to 2018-07-01
#    → Fetching GHCND:USW00013874 | 2018-07-01 to 2018-08-01
#    → Fetching GHCND:USW00013874 | 2018-08-01 to 2018-09-01
#    → Fetching GHCND:USW00013874 | 2018-09-01 to 2018-10-01
#    → Fetching GHCND:USW00013874 | 2018-10-01 to 2018-11-01
#    → Fetching GHCND:USW00013874 | 2018-11-01 to 2018-12-01
#    → Fetching GHCND:USW00013874 | 2018-12-01 to 2019-01-01
#    → Fetching GHCND:USW00013874 | 2019-01-01 to 2019-02-01
#    → Fetching GHCND:USW00013874 | 2019-02-01 to 2019-03-01
#    → Fetching GHCND:USW00013874 | 2019-03-01 to 2019-04-01
#    → Fetching GHCND:USW00013874 | 2019-04-01 to 2019-05-01
#    → Fetching GHCND:USW00013874 | 2019-05-01 to 2019-06-01
#    → Fetching GHCND:USW00013874 | 2019-06-01 to 2019-07-01
#    → Fetching GHCND:USW00013874 | 2019-07-01 to 2019-08-01
#    → Fetching GHCND:USW00013874 | 2019-08-01 to 2019-09-01
#    → Fetching GHCND:USW00013874 | 2019-09-01 to 2019-10-01
#    → Fetching GHCND:USW00013874 | 2019-10-01 to 2019-11-01
#    → Fetching GHCND:USW00013874 | 2019-11-01 to 2019-12-01
#    → Fetching GHCND:USW00013874 | 2019-12-01 to 2020-01-01
#    → Fetching GHCND:USW00013874 | 2020-01-01 to 2020-02-01
#    → Fetching GHCND:USW00013874 | 2020-02-01 to 2020-03-01
#    → Fetching GHCND:USW00013874 | 2020-03-01 to 2020-04-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00013874 | 2020-04-01 to 2020-05-01
#    → Fetching GHCND:USW00013874 | 2020-05-01 to 2020-06-01
#    → Fetching GHCND:USW00013874 | 2020-06-01 to 2020-07-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00013874 | 2020-07-01 to 2020-08-01
#    → Fetching GHCND:USW00013874 | 2020-08-01 to 2020-09-01
#    → Fetching GHCND:USW00013874 | 2020-09-01 to 2020-10-01
#    → Fetching GHCND:USW00013874 | 2020-10-01 to 2020-11-01
#    → Fetching GHCND:USW00013874 | 2020-11-01 to 2020-12-01
#    → Fetching GHCND:USW00013874 | 2020-12-01 to 2021-01-01
#    → Fetching GHCND:USW00013874 | 2021-01-01 to 2021-02-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00013874 | 2021-02-01 to 2021-03-01
#    → Fetching GHCND:USW00013874 | 2021-03-01 to 2021-04-01
#    → Fetching GHCND:USW00013874 | 2021-04-01 to 2021-05-01
#    → Fetching GHCND:USW00013874 | 2021-05-01 to 2021-06-01
#    → Fetching GHCND:USW00013874 | 2021-06-01 to 2021-07-01
#    → Fetching GHCND:USW00013874 | 2021-07-01 to 2021-08-01
#    → Fetching GHCND:USW00013874 | 2021-08-01 to 2021-09-01
#    → Fetching GHCND:USW00013874 | 2021-09-01 to 2021-10-01
#    → Fetching GHCND:USW00013874 | 2021-10-01 to 2021-11-01
#    → Fetching GHCND:USW00013874 | 2021-11-01 to 2021-12-01
#    → Fetching GHCND:USW00013874 | 2021-12-01 to 2022-01-01
#    → Fetching GHCND:USW00013874 | 2022-01-01 to 2022-02-01
#    → Fetching GHCND:USW00013874 | 2022-02-01 to 2022-03-01
#    → Fetching GHCND:USW00013874 | 2022-03-01 to 2022-04-01
#    → Fetching GHCND:USW00013874 | 2022-04-01 to 2022-05-01
#    → Fetching GHCND:USW00013874 | 2022-05-01 to 2022-06-01
#    → Fetching GHCND:USW00013874 | 2022-06-01 to 2022-07-01
#    → Fetching GHCND:USW00013874 | 2022-07-01 to 2022-08-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00013874 | 2022-08-01 to 2022-09-01
#    → Fetching GHCND:USW00013874 | 2022-09-01 to 2022-10-01
#    → Fetching GHCND:USW00013874 | 2022-10-01 to 2022-11-01
#    → Fetching GHCND:USW00013874 | 2022-11-01 to 2022-12-01
#    → Fetching GHCND:USW00013874 | 2022-12-01 to 2023-01-01
#    → Fetching GHCND:USW00013874 | 2023-01-01 to 2023-02-01
#    → Fetching GHCND:USW00013874 | 2023-02-01 to 2023-03-01
#    → Fetching GHCND:USW00013874 | 2023-03-01 to 2023-04-01
#    → Fetching GHCND:USW00013874 | 2023-04-01 to 2023-05-01
#    → Fetching GHCND:USW00013874 | 2023-05-01 to 2023-06-01
#    → Fetching GHCND:USW00013874 | 2023-06-01 to 2023-07-01
#    → Fetching GHCND:USW00013874 | 2023-07-01 to 2023-08-01
#    → Fetching GHCND:USW00013874 | 2023-08-01 to 2023-09-01
#    → Fetching GHCND:USW00013874 | 2023-09-01 to 2023-10-01
#    → Fetching GHCND:USW00013874 | 2023-10-01 to 2023-11-01
#    → Fetching GHCND:USW00013874 | 2023-11-01 to 2023-12-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00013874 | 2023-12-01 to 2024-01-01
#    → Fetching GHCND:USW00013874 | 2024-01-01 to 2024-02-01
#    → Fetching GHCND:USW00013874 | 2024-02-01 to 2024-03-01
#    → Fetching GHCND:USW00013874 | 2024-03-01 to 2024-04-01
#    → Fetching GHCND:USW00013874 | 2024-04-01 to 2024-05-01
#    → Fetching GHCND:USW00013874 | 2024-05-01 to 2024-06-01
#    → Fetching GHCND:USW00013874 | 2024-06-01 to 2024-07-01
#    → Fetching GHCND:USW00013874 | 2024-07-01 to 2024-08-01
#    → Fetching GHCND:USW00013874 | 2024-08-01 to 2024-09-01
#    → Fetching GHCND:USW00013874 | 2024-09-01 to 2024-10-01
#    → Fetching GHCND:USW00013874 | 2024-10-01 to 2024-11-01
#    → Fetching GHCND:USW00013874 | 2024-11-01 to 2024-12-01
#    → Fetching GHCND:USW00013874 | 2024-12-01 to 2025-01-01
#    ✅ Completed ATL: 3584 rows
#
# 📡 Fetching weather for DFW (GHCND:USW00003927)
#    → Fetching GHCND:USW00003927 | 2015-01-01 to 2015-02-01
#    → Fetching GHCND:USW00003927 | 2015-02-01 to 2015-03-01
#    → Fetching GHCND:USW00003927 | 2015-03-01 to 2015-04-01
#    → Fetching GHCND:USW00003927 | 2015-04-01 to 2015-05-01
#    → Fetching GHCND:USW00003927 | 2015-05-01 to 2015-06-01
#    → Fetching GHCND:USW00003927 | 2015-06-01 to 2015-07-01
#    → Fetching GHCND:USW00003927 | 2015-07-01 to 2015-08-01
#    → Fetching GHCND:USW00003927 | 2015-08-01 to 2015-09-01
#    → Fetching GHCND:USW00003927 | 2015-09-01 to 2015-10-01
#    → Fetching GHCND:USW00003927 | 2015-10-01 to 2015-11-01
#    → Fetching GHCND:USW00003927 | 2015-11-01 to 2015-12-01
#    → Fetching GHCND:USW00003927 | 2015-12-01 to 2016-01-01
#    → Fetching GHCND:USW00003927 | 2016-01-01 to 2016-02-01
#    → Fetching GHCND:USW00003927 | 2016-02-01 to 2016-03-01
#    → Fetching GHCND:USW00003927 | 2016-03-01 to 2016-04-01
#    → Fetching GHCND:USW00003927 | 2016-04-01 to 2016-05-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00003927 | 2016-05-01 to 2016-06-01
#    → Fetching GHCND:USW00003927 | 2016-06-01 to 2016-07-01
#    → Fetching GHCND:USW00003927 | 2016-07-01 to 2016-08-01
#    → Fetching GHCND:USW00003927 | 2016-08-01 to 2016-09-01
#    → Fetching GHCND:USW00003927 | 2016-09-01 to 2016-10-01
#    → Fetching GHCND:USW00003927 | 2016-10-01 to 2016-11-01
#    → Fetching GHCND:USW00003927 | 2016-11-01 to 2016-12-01
#    → Fetching GHCND:USW00003927 | 2016-12-01 to 2017-01-01
#    → Fetching GHCND:USW00003927 | 2017-01-01 to 2017-02-01
#    → Fetching GHCND:USW00003927 | 2017-02-01 to 2017-03-01
#    → Fetching GHCND:USW00003927 | 2017-03-01 to 2017-04-01
#    → Fetching GHCND:USW00003927 | 2017-04-01 to 2017-05-01
#    → Fetching GHCND:USW00003927 | 2017-05-01 to 2017-06-01
#    → Fetching GHCND:USW00003927 | 2017-06-01 to 2017-07-01
#    → Fetching GHCND:USW00003927 | 2017-07-01 to 2017-08-01
#    → Fetching GHCND:USW00003927 | 2017-08-01 to 2017-09-01
#    → Fetching GHCND:USW00003927 | 2017-09-01 to 2017-10-01
#    → Fetching GHCND:USW00003927 | 2017-10-01 to 2017-11-01
#    → Fetching GHCND:USW00003927 | 2017-11-01 to 2017-12-01
#    → Fetching GHCND:USW00003927 | 2017-12-01 to 2018-01-01
#    → Fetching GHCND:USW00003927 | 2018-01-01 to 2018-02-01
#    → Fetching GHCND:USW00003927 | 2018-02-01 to 2018-03-01
#    → Fetching GHCND:USW00003927 | 2018-03-01 to 2018-04-01
#    → Fetching GHCND:USW00003927 | 2018-04-01 to 2018-05-01
#    → Fetching GHCND:USW00003927 | 2018-05-01 to 2018-06-01
#    → Fetching GHCND:USW00003927 | 2018-06-01 to 2018-07-01
#    → Fetching GHCND:USW00003927 | 2018-07-01 to 2018-08-01
#    → Fetching GHCND:USW00003927 | 2018-08-01 to 2018-09-01
#    → Fetching GHCND:USW00003927 | 2018-09-01 to 2018-10-01
#    → Fetching GHCND:USW00003927 | 2018-10-01 to 2018-11-01
#    → Fetching GHCND:USW00003927 | 2018-11-01 to 2018-12-01
#    → Fetching GHCND:USW00003927 | 2018-12-01 to 2019-01-01
#    → Fetching GHCND:USW00003927 | 2019-01-01 to 2019-02-01
#    → Fetching GHCND:USW00003927 | 2019-02-01 to 2019-03-01
#    → Fetching GHCND:USW00003927 | 2019-03-01 to 2019-04-01
#    → Fetching GHCND:USW00003927 | 2019-04-01 to 2019-05-01
#    → Fetching GHCND:USW00003927 | 2019-05-01 to 2019-06-01
#    → Fetching GHCND:USW00003927 | 2019-06-01 to 2019-07-01
#    → Fetching GHCND:USW00003927 | 2019-07-01 to 2019-08-01
#    → Fetching GHCND:USW00003927 | 2019-08-01 to 2019-09-01
#    → Fetching GHCND:USW00003927 | 2019-09-01 to 2019-10-01
#    → Fetching GHCND:USW00003927 | 2019-10-01 to 2019-11-01
#    → Fetching GHCND:USW00003927 | 2019-11-01 to 2019-12-01
#    → Fetching GHCND:USW00003927 | 2019-12-01 to 2020-01-01
#    → Fetching GHCND:USW00003927 | 2020-01-01 to 2020-02-01
#    → Fetching GHCND:USW00003927 | 2020-02-01 to 2020-03-01
#    → Fetching GHCND:USW00003927 | 2020-03-01 to 2020-04-01
#    → Fetching GHCND:USW00003927 | 2020-04-01 to 2020-05-01
#    → Fetching GHCND:USW00003927 | 2020-05-01 to 2020-06-01
#    → Fetching GHCND:USW00003927 | 2020-06-01 to 2020-07-01
#    → Fetching GHCND:USW00003927 | 2020-07-01 to 2020-08-01
#    → Fetching GHCND:USW00003927 | 2020-08-01 to 2020-09-01
#    → Fetching GHCND:USW00003927 | 2020-09-01 to 2020-10-01
#    → Fetching GHCND:USW00003927 | 2020-10-01 to 2020-11-01
#    → Fetching GHCND:USW00003927 | 2020-11-01 to 2020-12-01
#    → Fetching GHCND:USW00003927 | 2020-12-01 to 2021-01-01
#    → Fetching GHCND:USW00003927 | 2021-01-01 to 2021-02-01
#    → Fetching GHCND:USW00003927 | 2021-02-01 to 2021-03-01
#    → Fetching GHCND:USW00003927 | 2021-03-01 to 2021-04-01
#    → Fetching GHCND:USW00003927 | 2021-04-01 to 2021-05-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00003927 | 2021-05-01 to 2021-06-01
#    → Fetching GHCND:USW00003927 | 2021-06-01 to 2021-07-01
#    → Fetching GHCND:USW00003927 | 2021-07-01 to 2021-08-01
#    → Fetching GHCND:USW00003927 | 2021-08-01 to 2021-09-01
#    → Fetching GHCND:USW00003927 | 2021-09-01 to 2021-10-01
#    → Fetching GHCND:USW00003927 | 2021-10-01 to 2021-11-01
#    → Fetching GHCND:USW00003927 | 2021-11-01 to 2021-12-01
#    → Fetching GHCND:USW00003927 | 2021-12-01 to 2022-01-01
#    → Fetching GHCND:USW00003927 | 2022-01-01 to 2022-02-01
#    → Fetching GHCND:USW00003927 | 2022-02-01 to 2022-03-01
#    → Fetching GHCND:USW00003927 | 2022-03-01 to 2022-04-01
#    → Fetching GHCND:USW00003927 | 2022-04-01 to 2022-05-01
#    → Fetching GHCND:USW00003927 | 2022-05-01 to 2022-06-01
#    → Fetching GHCND:USW00003927 | 2022-06-01 to 2022-07-01
#    → Fetching GHCND:USW00003927 | 2022-07-01 to 2022-08-01
#    → Fetching GHCND:USW00003927 | 2022-08-01 to 2022-09-01
#    → Fetching GHCND:USW00003927 | 2022-09-01 to 2022-10-01
#    → Fetching GHCND:USW00003927 | 2022-10-01 to 2022-11-01
#    → Fetching GHCND:USW00003927 | 2022-11-01 to 2022-12-01
#    → Fetching GHCND:USW00003927 | 2022-12-01 to 2023-01-01
#    → Fetching GHCND:USW00003927 | 2023-01-01 to 2023-02-01
#    → Fetching GHCND:USW00003927 | 2023-02-01 to 2023-03-01
#    → Fetching GHCND:USW00003927 | 2023-03-01 to 2023-04-01
#    → Fetching GHCND:USW00003927 | 2023-04-01 to 2023-05-01
#    → Fetching GHCND:USW00003927 | 2023-05-01 to 2023-06-01
#    → Fetching GHCND:USW00003927 | 2023-06-01 to 2023-07-01
#    → Fetching GHCND:USW00003927 | 2023-07-01 to 2023-08-01
#    → Fetching GHCND:USW00003927 | 2023-08-01 to 2023-09-01
#    → Fetching GHCND:USW00003927 | 2023-09-01 to 2023-10-01
#    → Fetching GHCND:USW00003927 | 2023-10-01 to 2023-11-01
#    → Fetching GHCND:USW00003927 | 2023-11-01 to 2023-12-01
#    → Fetching GHCND:USW00003927 | 2023-12-01 to 2024-01-01
#    → Fetching GHCND:USW00003927 | 2024-01-01 to 2024-02-01
#    → Fetching GHCND:USW00003927 | 2024-02-01 to 2024-03-01
#    → Fetching GHCND:USW00003927 | 2024-03-01 to 2024-04-01
#    → Fetching GHCND:USW00003927 | 2024-04-01 to 2024-05-01
#    → Fetching GHCND:USW00003927 | 2024-05-01 to 2024-06-01
#    → Fetching GHCND:USW00003927 | 2024-06-01 to 2024-07-01
#    → Fetching GHCND:USW00003927 | 2024-07-01 to 2024-08-01
#    → Fetching GHCND:USW00003927 | 2024-08-01 to 2024-09-01
#    → Fetching GHCND:USW00003927 | 2024-09-01 to 2024-10-01
#    → Fetching GHCND:USW00003927 | 2024-10-01 to 2024-11-01
#    → Fetching GHCND:USW00003927 | 2024-11-01 to 2024-12-01
#    → Fetching GHCND:USW00003927 | 2024-12-01 to 2025-01-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    ✅ Completed DFW: 3741 rows
#
# 📡 Fetching weather for DEN (GHCND:USW00003017)
#    → Fetching GHCND:USW00003017 | 2015-01-01 to 2015-02-01
#    → Fetching GHCND:USW00003017 | 2015-02-01 to 2015-03-01
#    → Fetching GHCND:USW00003017 | 2015-03-01 to 2015-04-01
#    → Fetching GHCND:USW00003017 | 2015-04-01 to 2015-05-01
#    → Fetching GHCND:USW00003017 | 2015-05-01 to 2015-06-01
#    → Fetching GHCND:USW00003017 | 2015-06-01 to 2015-07-01
#    → Fetching GHCND:USW00003017 | 2015-07-01 to 2015-08-01
#    → Fetching GHCND:USW00003017 | 2015-08-01 to 2015-09-01
#    → Fetching GHCND:USW00003017 | 2015-09-01 to 2015-10-01
#    → Fetching GHCND:USW00003017 | 2015-10-01 to 2015-11-01
#    → Fetching GHCND:USW00003017 | 2015-11-01 to 2015-12-01
#    → Fetching GHCND:USW00003017 | 2015-12-01 to 2016-01-01
#    → Fetching GHCND:USW00003017 | 2016-01-01 to 2016-02-01
#    → Fetching GHCND:USW00003017 | 2016-02-01 to 2016-03-01
#    → Fetching GHCND:USW00003017 | 2016-03-01 to 2016-04-01
#    → Fetching GHCND:USW00003017 | 2016-04-01 to 2016-05-01
#    → Fetching GHCND:USW00003017 | 2016-05-01 to 2016-06-01
#    → Fetching GHCND:USW00003017 | 2016-06-01 to 2016-07-01
#    → Fetching GHCND:USW00003017 | 2016-07-01 to 2016-08-01
#    → Fetching GHCND:USW00003017 | 2016-08-01 to 2016-09-01
#    → Fetching GHCND:USW00003017 | 2016-09-01 to 2016-10-01
#    → Fetching GHCND:USW00003017 | 2016-10-01 to 2016-11-01
#    → Fetching GHCND:USW00003017 | 2016-11-01 to 2016-12-01
#    → Fetching GHCND:USW00003017 | 2016-12-01 to 2017-01-01
#    → Fetching GHCND:USW00003017 | 2017-01-01 to 2017-02-01
#    → Fetching GHCND:USW00003017 | 2017-02-01 to 2017-03-01
#    → Fetching GHCND:USW00003017 | 2017-03-01 to 2017-04-01
#    → Fetching GHCND:USW00003017 | 2017-04-01 to 2017-05-01
#    → Fetching GHCND:USW00003017 | 2017-05-01 to 2017-06-01
#    → Fetching GHCND:USW00003017 | 2017-06-01 to 2017-07-01
#    → Fetching GHCND:USW00003017 | 2017-07-01 to 2017-08-01
#    → Fetching GHCND:USW00003017 | 2017-08-01 to 2017-09-01
#    → Fetching GHCND:USW00003017 | 2017-09-01 to 2017-10-01
#    → Fetching GHCND:USW00003017 | 2017-10-01 to 2017-11-01
#    → Fetching GHCND:USW00003017 | 2017-11-01 to 2017-12-01
#    → Fetching GHCND:USW00003017 | 2017-12-01 to 2018-01-01
#    → Fetching GHCND:USW00003017 | 2018-01-01 to 2018-02-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00003017 | 2018-02-01 to 2018-03-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00003017 | 2018-03-01 to 2018-04-01
#    → Fetching GHCND:USW00003017 | 2018-04-01 to 2018-05-01
#    → Fetching GHCND:USW00003017 | 2018-05-01 to 2018-06-01
#    → Fetching GHCND:USW00003017 | 2018-06-01 to 2018-07-01
#    → Fetching GHCND:USW00003017 | 2018-07-01 to 2018-08-01
#    → Fetching GHCND:USW00003017 | 2018-08-01 to 2018-09-01
#    → Fetching GHCND:USW00003017 | 2018-09-01 to 2018-10-01
#    → Fetching GHCND:USW00003017 | 2018-10-01 to 2018-11-01
#    → Fetching GHCND:USW00003017 | 2018-11-01 to 2018-12-01
#    → Fetching GHCND:USW00003017 | 2018-12-01 to 2019-01-01
#    → Fetching GHCND:USW00003017 | 2019-01-01 to 2019-02-01
#    → Fetching GHCND:USW00003017 | 2019-02-01 to 2019-03-01
#    → Fetching GHCND:USW00003017 | 2019-03-01 to 2019-04-01
#    → Fetching GHCND:USW00003017 | 2019-04-01 to 2019-05-01
#    → Fetching GHCND:USW00003017 | 2019-05-01 to 2019-06-01
#    → Fetching GHCND:USW00003017 | 2019-06-01 to 2019-07-01
#    → Fetching GHCND:USW00003017 | 2019-07-01 to 2019-08-01
#    → Fetching GHCND:USW00003017 | 2019-08-01 to 2019-09-01
#    → Fetching GHCND:USW00003017 | 2019-09-01 to 2019-10-01
#    → Fetching GHCND:USW00003017 | 2019-10-01 to 2019-11-01
#    → Fetching GHCND:USW00003017 | 2019-11-01 to 2019-12-01
#    → Fetching GHCND:USW00003017 | 2019-12-01 to 2020-01-01
#    → Fetching GHCND:USW00003017 | 2020-01-01 to 2020-02-01
#    → Fetching GHCND:USW00003017 | 2020-02-01 to 2020-03-01
#    → Fetching GHCND:USW00003017 | 2020-03-01 to 2020-04-01
#    → Fetching GHCND:USW00003017 | 2020-04-01 to 2020-05-01
#    → Fetching GHCND:USW00003017 | 2020-05-01 to 2020-06-01
#    → Fetching GHCND:USW00003017 | 2020-06-01 to 2020-07-01
#    → Fetching GHCND:USW00003017 | 2020-07-01 to 2020-08-01
#    → Fetching GHCND:USW00003017 | 2020-08-01 to 2020-09-01
#    → Fetching GHCND:USW00003017 | 2020-09-01 to 2020-10-01
#    → Fetching GHCND:USW00003017 | 2020-10-01 to 2020-11-01
#    → Fetching GHCND:USW00003017 | 2020-11-01 to 2020-12-01
#    → Fetching GHCND:USW00003017 | 2020-12-01 to 2021-01-01
#    → Fetching GHCND:USW00003017 | 2021-01-01 to 2021-02-01
#    → Fetching GHCND:USW00003017 | 2021-02-01 to 2021-03-01
#    → Fetching GHCND:USW00003017 | 2021-03-01 to 2021-04-01
#    → Fetching GHCND:USW00003017 | 2021-04-01 to 2021-05-01
#    → Fetching GHCND:USW00003017 | 2021-05-01 to 2021-06-01
#    → Fetching GHCND:USW00003017 | 2021-06-01 to 2021-07-01
#    → Fetching GHCND:USW00003017 | 2021-07-01 to 2021-08-01
#    → Fetching GHCND:USW00003017 | 2021-08-01 to 2021-09-01
#    → Fetching GHCND:USW00003017 | 2021-09-01 to 2021-10-01
#    → Fetching GHCND:USW00003017 | 2021-10-01 to 2021-11-01
#    → Fetching GHCND:USW00003017 | 2021-11-01 to 2021-12-01
#    → Fetching GHCND:USW00003017 | 2021-12-01 to 2022-01-01
#    → Fetching GHCND:USW00003017 | 2022-01-01 to 2022-02-01
#    → Fetching GHCND:USW00003017 | 2022-02-01 to 2022-03-01
#    → Fetching GHCND:USW00003017 | 2022-03-01 to 2022-04-01
#    → Fetching GHCND:USW00003017 | 2022-04-01 to 2022-05-01
#    → Fetching GHCND:USW00003017 | 2022-05-01 to 2022-06-01
#    → Fetching GHCND:USW00003017 | 2022-06-01 to 2022-07-01
#    → Fetching GHCND:USW00003017 | 2022-07-01 to 2022-08-01
#    → Fetching GHCND:USW00003017 | 2022-08-01 to 2022-09-01
#    → Fetching GHCND:USW00003017 | 2022-09-01 to 2022-10-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00003017 | 2022-10-01 to 2022-11-01
#    → Fetching GHCND:USW00003017 | 2022-11-01 to 2022-12-01
#    → Fetching GHCND:USW00003017 | 2022-12-01 to 2023-01-01
#    → Fetching GHCND:USW00003017 | 2023-01-01 to 2023-02-01
#    → Fetching GHCND:USW00003017 | 2023-02-01 to 2023-03-01
#    → Fetching GHCND:USW00003017 | 2023-03-01 to 2023-04-01
#    → Fetching GHCND:USW00003017 | 2023-04-01 to 2023-05-01
#    → Fetching GHCND:USW00003017 | 2023-05-01 to 2023-06-01
#    → Fetching GHCND:USW00003017 | 2023-06-01 to 2023-07-01
#    → Fetching GHCND:USW00003017 | 2023-07-01 to 2023-08-01
#    → Fetching GHCND:USW00003017 | 2023-08-01 to 2023-09-01
#    → Fetching GHCND:USW00003017 | 2023-09-01 to 2023-10-01
#    → Fetching GHCND:USW00003017 | 2023-10-01 to 2023-11-01
#    → Fetching GHCND:USW00003017 | 2023-11-01 to 2023-12-01
#    → Fetching GHCND:USW00003017 | 2023-12-01 to 2024-01-01
#    → Fetching GHCND:USW00003017 | 2024-01-01 to 2024-02-01
#    → Fetching GHCND:USW00003017 | 2024-02-01 to 2024-03-01
#    → Fetching GHCND:USW00003017 | 2024-03-01 to 2024-04-01
#    → Fetching GHCND:USW00003017 | 2024-04-01 to 2024-05-01
#    → Fetching GHCND:USW00003017 | 2024-05-01 to 2024-06-01
#    → Fetching GHCND:USW00003017 | 2024-06-01 to 2024-07-01
#    → Fetching GHCND:USW00003017 | 2024-07-01 to 2024-08-01
#    → Fetching GHCND:USW00003017 | 2024-08-01 to 2024-09-01
#    → Fetching GHCND:USW00003017 | 2024-09-01 to 2024-10-01
#    → Fetching GHCND:USW00003017 | 2024-10-01 to 2024-11-01
#    → Fetching GHCND:USW00003017 | 2024-11-01 to 2024-12-01
#    → Fetching GHCND:USW00003017 | 2024-12-01 to 2025-01-01
#    ✅ Completed DEN: 3742 rows
#
# 📡 Fetching weather for ORD (GHCND:USW00094846)
#    → Fetching GHCND:USW00094846 | 2015-01-01 to 2015-02-01
#    → Fetching GHCND:USW00094846 | 2015-02-01 to 2015-03-01
#    → Fetching GHCND:USW00094846 | 2015-03-01 to 2015-04-01
#    → Fetching GHCND:USW00094846 | 2015-04-01 to 2015-05-01
#    → Fetching GHCND:USW00094846 | 2015-05-01 to 2015-06-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00094846 | 2015-06-01 to 2015-07-01
#    → Fetching GHCND:USW00094846 | 2015-07-01 to 2015-08-01
#    → Fetching GHCND:USW00094846 | 2015-08-01 to 2015-09-01
#    → Fetching GHCND:USW00094846 | 2015-09-01 to 2015-10-01
#    → Fetching GHCND:USW00094846 | 2015-10-01 to 2015-11-01
#    → Fetching GHCND:USW00094846 | 2015-11-01 to 2015-12-01
#    → Fetching GHCND:USW00094846 | 2015-12-01 to 2016-01-01
#    → Fetching GHCND:USW00094846 | 2016-01-01 to 2016-02-01
#    → Fetching GHCND:USW00094846 | 2016-02-01 to 2016-03-01
#    → Fetching GHCND:USW00094846 | 2016-03-01 to 2016-04-01
#    → Fetching GHCND:USW00094846 | 2016-04-01 to 2016-05-01
#    → Fetching GHCND:USW00094846 | 2016-05-01 to 2016-06-01
#    → Fetching GHCND:USW00094846 | 2016-06-01 to 2016-07-01
#    → Fetching GHCND:USW00094846 | 2016-07-01 to 2016-08-01
#    → Fetching GHCND:USW00094846 | 2016-08-01 to 2016-09-01
#    → Fetching GHCND:USW00094846 | 2016-09-01 to 2016-10-01
#    → Fetching GHCND:USW00094846 | 2016-10-01 to 2016-11-01
#    → Fetching GHCND:USW00094846 | 2016-11-01 to 2016-12-01
#    → Fetching GHCND:USW00094846 | 2016-12-01 to 2017-01-01
#    → Fetching GHCND:USW00094846 | 2017-01-01 to 2017-02-01
#    → Fetching GHCND:USW00094846 | 2017-02-01 to 2017-03-01
#    → Fetching GHCND:USW00094846 | 2017-03-01 to 2017-04-01
#    → Fetching GHCND:USW00094846 | 2017-04-01 to 2017-05-01
#    → Fetching GHCND:USW00094846 | 2017-05-01 to 2017-06-01
#    → Fetching GHCND:USW00094846 | 2017-06-01 to 2017-07-01
#    → Fetching GHCND:USW00094846 | 2017-07-01 to 2017-08-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00094846 | 2017-08-01 to 2017-09-01
#    → Fetching GHCND:USW00094846 | 2017-09-01 to 2017-10-01
#    → Fetching GHCND:USW00094846 | 2017-10-01 to 2017-11-01
#    → Fetching GHCND:USW00094846 | 2017-11-01 to 2017-12-01
#    → Fetching GHCND:USW00094846 | 2017-12-01 to 2018-01-01
#    → Fetching GHCND:USW00094846 | 2018-01-01 to 2018-02-01
#    → Fetching GHCND:USW00094846 | 2018-02-01 to 2018-03-01
#    → Fetching GHCND:USW00094846 | 2018-03-01 to 2018-04-01
#    → Fetching GHCND:USW00094846 | 2018-04-01 to 2018-05-01
#    → Fetching GHCND:USW00094846 | 2018-05-01 to 2018-06-01
#    → Fetching GHCND:USW00094846 | 2018-06-01 to 2018-07-01
#    → Fetching GHCND:USW00094846 | 2018-07-01 to 2018-08-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00094846 | 2018-08-01 to 2018-09-01
#    → Fetching GHCND:USW00094846 | 2018-09-01 to 2018-10-01
#    → Fetching GHCND:USW00094846 | 2018-10-01 to 2018-11-01
#    → Fetching GHCND:USW00094846 | 2018-11-01 to 2018-12-01
#    → Fetching GHCND:USW00094846 | 2018-12-01 to 2019-01-01
#    → Fetching GHCND:USW00094846 | 2019-01-01 to 2019-02-01
#    → Fetching GHCND:USW00094846 | 2019-02-01 to 2019-03-01
#    → Fetching GHCND:USW00094846 | 2019-03-01 to 2019-04-01
#    → Fetching GHCND:USW00094846 | 2019-04-01 to 2019-05-01
#    → Fetching GHCND:USW00094846 | 2019-05-01 to 2019-06-01
#    → Fetching GHCND:USW00094846 | 2019-06-01 to 2019-07-01
#    → Fetching GHCND:USW00094846 | 2019-07-01 to 2019-08-01
#    → Fetching GHCND:USW00094846 | 2019-08-01 to 2019-09-01
#    → Fetching GHCND:USW00094846 | 2019-09-01 to 2019-10-01
#    → Fetching GHCND:USW00094846 | 2019-10-01 to 2019-11-01
#    → Fetching GHCND:USW00094846 | 2019-11-01 to 2019-12-01
#    → Fetching GHCND:USW00094846 | 2019-12-01 to 2020-01-01
#    → Fetching GHCND:USW00094846 | 2020-01-01 to 2020-02-01
#    → Fetching GHCND:USW00094846 | 2020-02-01 to 2020-03-01
#    → Fetching GHCND:USW00094846 | 2020-03-01 to 2020-04-01
#    → Fetching GHCND:USW00094846 | 2020-04-01 to 2020-05-01
#    → Fetching GHCND:USW00094846 | 2020-05-01 to 2020-06-01
#    → Fetching GHCND:USW00094846 | 2020-06-01 to 2020-07-01
#    → Fetching GHCND:USW00094846 | 2020-07-01 to 2020-08-01
#    → Fetching GHCND:USW00094846 | 2020-08-01 to 2020-09-01
#    → Fetching GHCND:USW00094846 | 2020-09-01 to 2020-10-01
#    → Fetching GHCND:USW00094846 | 2020-10-01 to 2020-11-01
#    → Fetching GHCND:USW00094846 | 2020-11-01 to 2020-12-01
#    → Fetching GHCND:USW00094846 | 2020-12-01 to 2021-01-01
#    → Fetching GHCND:USW00094846 | 2021-01-01 to 2021-02-01
#    → Fetching GHCND:USW00094846 | 2021-02-01 to 2021-03-01
#    → Fetching GHCND:USW00094846 | 2021-03-01 to 2021-04-01
#    → Fetching GHCND:USW00094846 | 2021-04-01 to 2021-05-01
#    → Fetching GHCND:USW00094846 | 2021-05-01 to 2021-06-01
#    → Fetching GHCND:USW00094846 | 2021-06-01 to 2021-07-01
#    → Fetching GHCND:USW00094846 | 2021-07-01 to 2021-08-01
#    → Fetching GHCND:USW00094846 | 2021-08-01 to 2021-09-01
#    → Fetching GHCND:USW00094846 | 2021-09-01 to 2021-10-01
#    → Fetching GHCND:USW00094846 | 2021-10-01 to 2021-11-01
#    → Fetching GHCND:USW00094846 | 2021-11-01 to 2021-12-01
#    → Fetching GHCND:USW00094846 | 2021-12-01 to 2022-01-01
#    → Fetching GHCND:USW00094846 | 2022-01-01 to 2022-02-01
#    → Fetching GHCND:USW00094846 | 2022-02-01 to 2022-03-01
#    → Fetching GHCND:USW00094846 | 2022-03-01 to 2022-04-01
#    → Fetching GHCND:USW00094846 | 2022-04-01 to 2022-05-01
#    → Fetching GHCND:USW00094846 | 2022-05-01 to 2022-06-01
#    → Fetching GHCND:USW00094846 | 2022-06-01 to 2022-07-01
#    → Fetching GHCND:USW00094846 | 2022-07-01 to 2022-08-01
#    → Fetching GHCND:USW00094846 | 2022-08-01 to 2022-09-01
#    → Fetching GHCND:USW00094846 | 2022-09-01 to 2022-10-01
#    → Fetching GHCND:USW00094846 | 2022-10-01 to 2022-11-01
#    → Fetching GHCND:USW00094846 | 2022-11-01 to 2022-12-01
#    → Fetching GHCND:USW00094846 | 2022-12-01 to 2023-01-01
#    → Fetching GHCND:USW00094846 | 2023-01-01 to 2023-02-01
#    → Fetching GHCND:USW00094846 | 2023-02-01 to 2023-03-01
#    → Fetching GHCND:USW00094846 | 2023-03-01 to 2023-04-01
#    → Fetching GHCND:USW00094846 | 2023-04-01 to 2023-05-01
#    → Fetching GHCND:USW00094846 | 2023-05-01 to 2023-06-01
#    → Fetching GHCND:USW00094846 | 2023-06-01 to 2023-07-01
#    → Fetching GHCND:USW00094846 | 2023-07-01 to 2023-08-01
#    → Fetching GHCND:USW00094846 | 2023-08-01 to 2023-09-01
#    → Fetching GHCND:USW00094846 | 2023-09-01 to 2023-10-01
#    → Fetching GHCND:USW00094846 | 2023-10-01 to 2023-11-01
#    → Fetching GHCND:USW00094846 | 2023-11-01 to 2023-12-01
#    → Fetching GHCND:USW00094846 | 2023-12-01 to 2024-01-01
#    → Fetching GHCND:USW00094846 | 2024-01-01 to 2024-02-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00094846 | 2024-02-01 to 2024-03-01
#    → Fetching GHCND:USW00094846 | 2024-03-01 to 2024-04-01
#    → Fetching GHCND:USW00094846 | 2024-04-01 to 2024-05-01
#    → Fetching GHCND:USW00094846 | 2024-05-01 to 2024-06-01
#    → Fetching GHCND:USW00094846 | 2024-06-01 to 2024-07-01
#    → Fetching GHCND:USW00094846 | 2024-07-01 to 2024-08-01
#    → Fetching GHCND:USW00094846 | 2024-08-01 to 2024-09-01
#    → Fetching GHCND:USW00094846 | 2024-09-01 to 2024-10-01
#    → Fetching GHCND:USW00094846 | 2024-10-01 to 2024-11-01
#    → Fetching GHCND:USW00094846 | 2024-11-01 to 2024-12-01
#    → Fetching GHCND:USW00094846 | 2024-12-01 to 2025-01-01
#    ✅ Completed ORD: 3741 rows
#
# 📡 Fetching weather for LAX (GHCND:USW00093134)
#    → Fetching GHCND:USW00093134 | 2015-01-01 to 2015-02-01
#    → Fetching GHCND:USW00093134 | 2015-02-01 to 2015-03-01
#    → Fetching GHCND:USW00093134 | 2015-03-01 to 2015-04-01
#    → Fetching GHCND:USW00093134 | 2015-04-01 to 2015-05-01
#    → Fetching GHCND:USW00093134 | 2015-05-01 to 2015-06-01
#    → Fetching GHCND:USW00093134 | 2015-06-01 to 2015-07-01
#    → Fetching GHCND:USW00093134 | 2015-07-01 to 2015-08-01
#    → Fetching GHCND:USW00093134 | 2015-08-01 to 2015-09-01
#    → Fetching GHCND:USW00093134 | 2015-09-01 to 2015-10-01
#    → Fetching GHCND:USW00093134 | 2015-10-01 to 2015-11-01
#    → Fetching GHCND:USW00093134 | 2015-11-01 to 2015-12-01
#    → Fetching GHCND:USW00093134 | 2015-12-01 to 2016-01-01
#    → Fetching GHCND:USW00093134 | 2016-01-01 to 2016-02-01
#    → Fetching GHCND:USW00093134 | 2016-02-01 to 2016-03-01
#    → Fetching GHCND:USW00093134 | 2016-03-01 to 2016-04-01
#    → Fetching GHCND:USW00093134 | 2016-04-01 to 2016-05-01
#    → Fetching GHCND:USW00093134 | 2016-05-01 to 2016-06-01
#    → Fetching GHCND:USW00093134 | 2016-06-01 to 2016-07-01
#    → Fetching GHCND:USW00093134 | 2016-07-01 to 2016-08-01
#    → Fetching GHCND:USW00093134 | 2016-08-01 to 2016-09-01
#    → Fetching GHCND:USW00093134 | 2016-09-01 to 2016-10-01
#    → Fetching GHCND:USW00093134 | 2016-10-01 to 2016-11-01
#    → Fetching GHCND:USW00093134 | 2016-11-01 to 2016-12-01
#    → Fetching GHCND:USW00093134 | 2016-12-01 to 2017-01-01
#    → Fetching GHCND:USW00093134 | 2017-01-01 to 2017-02-01
#    → Fetching GHCND:USW00093134 | 2017-02-01 to 2017-03-01
#    → Fetching GHCND:USW00093134 | 2017-03-01 to 2017-04-01
#    → Fetching GHCND:USW00093134 | 2017-04-01 to 2017-05-01
#    → Fetching GHCND:USW00093134 | 2017-05-01 to 2017-06-01
#    → Fetching GHCND:USW00093134 | 2017-06-01 to 2017-07-01
#    → Fetching GHCND:USW00093134 | 2017-07-01 to 2017-08-01
#    → Fetching GHCND:USW00093134 | 2017-08-01 to 2017-09-01
#    → Fetching GHCND:USW00093134 | 2017-09-01 to 2017-10-01
#    → Fetching GHCND:USW00093134 | 2017-10-01 to 2017-11-01
#    → Fetching GHCND:USW00093134 | 2017-11-01 to 2017-12-01
#    → Fetching GHCND:USW00093134 | 2017-12-01 to 2018-01-01
#    → Fetching GHCND:USW00093134 | 2018-01-01 to 2018-02-01
#    → Fetching GHCND:USW00093134 | 2018-02-01 to 2018-03-01
#    → Fetching GHCND:USW00093134 | 2018-03-01 to 2018-04-01
#    → Fetching GHCND:USW00093134 | 2018-04-01 to 2018-05-01
#    → Fetching GHCND:USW00093134 | 2018-05-01 to 2018-06-01
#    → Fetching GHCND:USW00093134 | 2018-06-01 to 2018-07-01
#    → Fetching GHCND:USW00093134 | 2018-07-01 to 2018-08-01
#    → Fetching GHCND:USW00093134 | 2018-08-01 to 2018-09-01
#    → Fetching GHCND:USW00093134 | 2018-09-01 to 2018-10-01
#    → Fetching GHCND:USW00093134 | 2018-10-01 to 2018-11-01
#    → Fetching GHCND:USW00093134 | 2018-11-01 to 2018-12-01
#    → Fetching GHCND:USW00093134 | 2018-12-01 to 2019-01-01
#    → Fetching GHCND:USW00093134 | 2019-01-01 to 2019-02-01
#    → Fetching GHCND:USW00093134 | 2019-02-01 to 2019-03-01
#    → Fetching GHCND:USW00093134 | 2019-03-01 to 2019-04-01
#    → Fetching GHCND:USW00093134 | 2019-04-01 to 2019-05-01
#    → Fetching GHCND:USW00093134 | 2019-05-01 to 2019-06-01
#    → Fetching GHCND:USW00093134 | 2019-06-01 to 2019-07-01
#    → Fetching GHCND:USW00093134 | 2019-07-01 to 2019-08-01
#    → Fetching GHCND:USW00093134 | 2019-08-01 to 2019-09-01
#    → Fetching GHCND:USW00093134 | 2019-09-01 to 2019-10-01
#    → Fetching GHCND:USW00093134 | 2019-10-01 to 2019-11-01
#    → Fetching GHCND:USW00093134 | 2019-11-01 to 2019-12-01
#    → Fetching GHCND:USW00093134 | 2019-12-01 to 2020-01-01
#    → Fetching GHCND:USW00093134 | 2020-01-01 to 2020-02-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00093134 | 2020-02-01 to 2020-03-01
#    → Fetching GHCND:USW00093134 | 2020-03-01 to 2020-04-01
#    → Fetching GHCND:USW00093134 | 2020-04-01 to 2020-05-01
#    → Fetching GHCND:USW00093134 | 2020-05-01 to 2020-06-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00093134 | 2020-06-01 to 2020-07-01
#    → Fetching GHCND:USW00093134 | 2020-07-01 to 2020-08-01
#    → Fetching GHCND:USW00093134 | 2020-08-01 to 2020-09-01
#    → Fetching GHCND:USW00093134 | 2020-09-01 to 2020-10-01
#    → Fetching GHCND:USW00093134 | 2020-10-01 to 2020-11-01
#    → Fetching GHCND:USW00093134 | 2020-11-01 to 2020-12-01
#    → Fetching GHCND:USW00093134 | 2020-12-01 to 2021-01-01
#    → Fetching GHCND:USW00093134 | 2021-01-01 to 2021-02-01
#    → Fetching GHCND:USW00093134 | 2021-02-01 to 2021-03-01
#    → Fetching GHCND:USW00093134 | 2021-03-01 to 2021-04-01
#    → Fetching GHCND:USW00093134 | 2021-04-01 to 2021-05-01
#    → Fetching GHCND:USW00093134 | 2021-05-01 to 2021-06-01
#    → Fetching GHCND:USW00093134 | 2021-06-01 to 2021-07-01
#    → Fetching GHCND:USW00093134 | 2021-07-01 to 2021-08-01
#    → Fetching GHCND:USW00093134 | 2021-08-01 to 2021-09-01
#    → Fetching GHCND:USW00093134 | 2021-09-01 to 2021-10-01
#    → Fetching GHCND:USW00093134 | 2021-10-01 to 2021-11-01
#    → Fetching GHCND:USW00093134 | 2021-11-01 to 2021-12-01
#    → Fetching GHCND:USW00093134 | 2021-12-01 to 2022-01-01
#    → Fetching GHCND:USW00093134 | 2022-01-01 to 2022-02-01
#    → Fetching GHCND:USW00093134 | 2022-02-01 to 2022-03-01
#    → Fetching GHCND:USW00093134 | 2022-03-01 to 2022-04-01
#    → Fetching GHCND:USW00093134 | 2022-04-01 to 2022-05-01
#    → Fetching GHCND:USW00093134 | 2022-05-01 to 2022-06-01
#    → Fetching GHCND:USW00093134 | 2022-06-01 to 2022-07-01
#    → Fetching GHCND:USW00093134 | 2022-07-01 to 2022-08-01
#    → Fetching GHCND:USW00093134 | 2022-08-01 to 2022-09-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00093134 | 2022-09-01 to 2022-10-01
#    → Fetching GHCND:USW00093134 | 2022-10-01 to 2022-11-01
#    → Fetching GHCND:USW00093134 | 2022-11-01 to 2022-12-01
#    → Fetching GHCND:USW00093134 | 2022-12-01 to 2023-01-01
#    → Fetching GHCND:USW00093134 | 2023-01-01 to 2023-02-01
#    → Fetching GHCND:USW00093134 | 2023-02-01 to 2023-03-01
#    → Fetching GHCND:USW00093134 | 2023-03-01 to 2023-04-01
#    → Fetching GHCND:USW00093134 | 2023-04-01 to 2023-05-01
#    → Fetching GHCND:USW00093134 | 2023-05-01 to 2023-06-01
#    → Fetching GHCND:USW00093134 | 2023-06-01 to 2023-07-01
#    → Fetching GHCND:USW00093134 | 2023-07-01 to 2023-08-01
#    → Fetching GHCND:USW00093134 | 2023-08-01 to 2023-09-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00093134 | 2023-09-01 to 2023-10-01
#    → Fetching GHCND:USW00093134 | 2023-10-01 to 2023-11-01
#    → Fetching GHCND:USW00093134 | 2023-11-01 to 2023-12-01
#    → Fetching GHCND:USW00093134 | 2023-12-01 to 2024-01-01
#    → Fetching GHCND:USW00093134 | 2024-01-01 to 2024-02-01
#    → Fetching GHCND:USW00093134 | 2024-02-01 to 2024-03-01
#    → Fetching GHCND:USW00093134 | 2024-03-01 to 2024-04-01
#    → Fetching GHCND:USW00093134 | 2024-04-01 to 2024-05-01
#    → Fetching GHCND:USW00093134 | 2024-05-01 to 2024-06-01
#    → Fetching GHCND:USW00093134 | 2024-06-01 to 2024-07-01
#    → Fetching GHCND:USW00093134 | 2024-07-01 to 2024-08-01
#    → Fetching GHCND:USW00093134 | 2024-08-01 to 2024-09-01
#    → Fetching GHCND:USW00093134 | 2024-09-01 to 2024-10-01
#    → Fetching GHCND:USW00093134 | 2024-10-01 to 2024-11-01
#    → Fetching GHCND:USW00093134 | 2024-11-01 to 2024-12-01
#    → Fetching GHCND:USW00093134 | 2024-12-01 to 2025-01-01
#    ✅ Completed LAX: 3741 rows
#
# 📡 Fetching weather for CLT (GHCND:USW00013881)
#    → Fetching GHCND:USW00013881 | 2015-01-01 to 2015-02-01
#    → Fetching GHCND:USW00013881 | 2015-02-01 to 2015-03-01
#    → Fetching GHCND:USW00013881 | 2015-03-01 to 2015-04-01
#    → Fetching GHCND:USW00013881 | 2015-04-01 to 2015-05-01
#    → Fetching GHCND:USW00013881 | 2015-05-01 to 2015-06-01
#    → Fetching GHCND:USW00013881 | 2015-06-01 to 2015-07-01
#    → Fetching GHCND:USW00013881 | 2015-07-01 to 2015-08-01
#    → Fetching GHCND:USW00013881 | 2015-08-01 to 2015-09-01
#    → Fetching GHCND:USW00013881 | 2015-09-01 to 2015-10-01
#    → Fetching GHCND:USW00013881 | 2015-10-01 to 2015-11-01
#    → Fetching GHCND:USW00013881 | 2015-11-01 to 2015-12-01
#    → Fetching GHCND:USW00013881 | 2015-12-01 to 2016-01-01
#    → Fetching GHCND:USW00013881 | 2016-01-01 to 2016-02-01
#    → Fetching GHCND:USW00013881 | 2016-02-01 to 2016-03-01
#    → Fetching GHCND:USW00013881 | 2016-03-01 to 2016-04-01
#    → Fetching GHCND:USW00013881 | 2016-04-01 to 2016-05-01
#    → Fetching GHCND:USW00013881 | 2016-05-01 to 2016-06-01
#    → Fetching GHCND:USW00013881 | 2016-06-01 to 2016-07-01
#    → Fetching GHCND:USW00013881 | 2016-07-01 to 2016-08-01
#    → Fetching GHCND:USW00013881 | 2016-08-01 to 2016-09-01
#    → Fetching GHCND:USW00013881 | 2016-09-01 to 2016-10-01
#    → Fetching GHCND:USW00013881 | 2016-10-01 to 2016-11-01
#    → Fetching GHCND:USW00013881 | 2016-11-01 to 2016-12-01
#    → Fetching GHCND:USW00013881 | 2016-12-01 to 2017-01-01
#    → Fetching GHCND:USW00013881 | 2017-01-01 to 2017-02-01
#    → Fetching GHCND:USW00013881 | 2017-02-01 to 2017-03-01
#    → Fetching GHCND:USW00013881 | 2017-03-01 to 2017-04-01
#    → Fetching GHCND:USW00013881 | 2017-04-01 to 2017-05-01
#    → Fetching GHCND:USW00013881 | 2017-05-01 to 2017-06-01
#    → Fetching GHCND:USW00013881 | 2017-06-01 to 2017-07-01
#    → Fetching GHCND:USW00013881 | 2017-07-01 to 2017-08-01
#    → Fetching GHCND:USW00013881 | 2017-08-01 to 2017-09-01
#    → Fetching GHCND:USW00013881 | 2017-09-01 to 2017-10-01
#    → Fetching GHCND:USW00013881 | 2017-10-01 to 2017-11-01
#    → Fetching GHCND:USW00013881 | 2017-11-01 to 2017-12-01
#    → Fetching GHCND:USW00013881 | 2017-12-01 to 2018-01-01
#    → Fetching GHCND:USW00013881 | 2018-01-01 to 2018-02-01
#    → Fetching GHCND:USW00013881 | 2018-02-01 to 2018-03-01
#    → Fetching GHCND:USW00013881 | 2018-03-01 to 2018-04-01
#    → Fetching GHCND:USW00013881 | 2018-04-01 to 2018-05-01
#    → Fetching GHCND:USW00013881 | 2018-05-01 to 2018-06-01
#    → Fetching GHCND:USW00013881 | 2018-06-01 to 2018-07-01
#    → Fetching GHCND:USW00013881 | 2018-07-01 to 2018-08-01
#    → Fetching GHCND:USW00013881 | 2018-08-01 to 2018-09-01
#    → Fetching GHCND:USW00013881 | 2018-09-01 to 2018-10-01
#    → Fetching GHCND:USW00013881 | 2018-10-01 to 2018-11-01
#    → Fetching GHCND:USW00013881 | 2018-11-01 to 2018-12-01
#    → Fetching GHCND:USW00013881 | 2018-12-01 to 2019-01-01
#    → Fetching GHCND:USW00013881 | 2019-01-01 to 2019-02-01
# ...
#    → Fetching GHCND:USW00023234 | 2018-11-01 to 2018-12-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00023234 | 2018-12-01 to 2019-01-01
#    → Fetching GHCND:USW00023234 | 2019-01-01 to 2019-02-01
#    → Fetching GHCND:USW00023234 | 2019-02-01 to 2019-03-01
#    → Fetching GHCND:USW00023234 | 2019-03-01 to 2019-04-01
#    → Fetching GHCND:USW00023234 | 2019-04-01 to 2019-05-01
#    → Fetching GHCND:USW00023234 | 2019-05-01 to 2019-06-01
#    → Fetching GHCND:USW00023234 | 2019-06-01 to 2019-07-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00023234 | 2019-07-01 to 2019-08-01
#    → Fetching GHCND:USW00023234 | 2019-08-01 to 2019-09-01
#    → Fetching GHCND:USW00023234 | 2019-09-01 to 2019-10-01
#    → Fetching GHCND:USW00023234 | 2019-10-01 to 2019-11-01
#    → Fetching GHCND:USW00023234 | 2019-11-01 to 2019-12-01
#    → Fetching GHCND:USW00023234 | 2019-12-01 to 2020-01-01
#    → Fetching GHCND:USW00023234 | 2020-01-01 to 2020-02-01
#    → Fetching GHCND:USW00023234 | 2020-02-01 to 2020-03-01
#    → Fetching GHCND:USW00023234 | 2020-03-01 to 2020-04-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00023234 | 2020-04-01 to 2020-05-01
#    → Fetching GHCND:USW00023234 | 2020-05-01 to 2020-06-01
#    → Fetching GHCND:USW00023234 | 2020-06-01 to 2020-07-01
#    → Fetching GHCND:USW00023234 | 2020-07-01 to 2020-08-01
#    → Fetching GHCND:USW00023234 | 2020-08-01 to 2020-09-01
#    → Fetching GHCND:USW00023234 | 2020-09-01 to 2020-10-01
#    → Fetching GHCND:USW00023234 | 2020-10-01 to 2020-11-01
#    → Fetching GHCND:USW00023234 | 2020-11-01 to 2020-12-01
#    → Fetching GHCND:USW00023234 | 2020-12-01 to 2021-01-01
#    → Fetching GHCND:USW00023234 | 2021-01-01 to 2021-02-01
#    → Fetching GHCND:USW00023234 | 2021-02-01 to 2021-03-01
#    → Fetching GHCND:USW00023234 | 2021-03-01 to 2021-04-01
#    → Fetching GHCND:USW00023234 | 2021-04-01 to 2021-05-01
#    → Fetching GHCND:USW00023234 | 2021-05-01 to 2021-06-01
#    → Fetching GHCND:USW00023234 | 2021-06-01 to 2021-07-01
#    → Fetching GHCND:USW00023234 | 2021-07-01 to 2021-08-01
#    → Fetching GHCND:USW00023234 | 2021-08-01 to 2021-09-01
#    → Fetching GHCND:USW00023234 | 2021-09-01 to 2021-10-01
#    → Fetching GHCND:USW00023234 | 2021-10-01 to 2021-11-01
#    → Fetching GHCND:USW00023234 | 2021-11-01 to 2021-12-01
#    → Fetching GHCND:USW00023234 | 2021-12-01 to 2022-01-01
#    → Fetching GHCND:USW00023234 | 2022-01-01 to 2022-02-01
#    → Fetching GHCND:USW00023234 | 2022-02-01 to 2022-03-01
#    → Fetching GHCND:USW00023234 | 2022-03-01 to 2022-04-01
#    → Fetching GHCND:USW00023234 | 2022-04-01 to 2022-05-01
#    → Fetching GHCND:USW00023234 | 2022-05-01 to 2022-06-01
#    → Fetching GHCND:USW00023234 | 2022-06-01 to 2022-07-01
#    → Fetching GHCND:USW00023234 | 2022-07-01 to 2022-08-01
#    → Fetching GHCND:USW00023234 | 2022-08-01 to 2022-09-01
#    → Fetching GHCND:USW00023234 | 2022-09-01 to 2022-10-01
#    → Fetching GHCND:USW00023234 | 2022-10-01 to 2022-11-01
#    → Fetching GHCND:USW00023234 | 2022-11-01 to 2022-12-01
#    → Fetching GHCND:USW00023234 | 2022-12-01 to 2023-01-01
#    → Fetching GHCND:USW00023234 | 2023-01-01 to 2023-02-01
#    → Fetching GHCND:USW00023234 | 2023-02-01 to 2023-03-01
#    → Fetching GHCND:USW00023234 | 2023-03-01 to 2023-04-01
#    → Fetching GHCND:USW00023234 | 2023-04-01 to 2023-05-01
#    → Fetching GHCND:USW00023234 | 2023-05-01 to 2023-06-01
#    → Fetching GHCND:USW00023234 | 2023-06-01 to 2023-07-01
#    → Fetching GHCND:USW00023234 | 2023-07-01 to 2023-08-01
#    → Fetching GHCND:USW00023234 | 2023-08-01 to 2023-09-01
#    → Fetching GHCND:USW00023234 | 2023-09-01 to 2023-10-01
#    → Fetching GHCND:USW00023234 | 2023-10-01 to 2023-11-01
#    → Fetching GHCND:USW00023234 | 2023-11-01 to 2023-12-01
#    → Fetching GHCND:USW00023234 | 2023-12-01 to 2024-01-01
#    → Fetching GHCND:USW00023234 | 2024-01-01 to 2024-02-01
#    → Fetching GHCND:USW00023234 | 2024-02-01 to 2024-03-01
#    → Fetching GHCND:USW00023234 | 2024-03-01 to 2024-04-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00023234 | 2024-04-01 to 2024-05-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00023234 | 2024-05-01 to 2024-06-01
#    → Fetching GHCND:USW00023234 | 2024-06-01 to 2024-07-01
#    → Fetching GHCND:USW00023234 | 2024-07-01 to 2024-08-01
#    → Fetching GHCND:USW00023234 | 2024-08-01 to 2024-09-01
#    → Fetching GHCND:USW00023234 | 2024-09-01 to 2024-10-01
#    → Fetching GHCND:USW00023234 | 2024-10-01 to 2024-11-01
#    → Fetching GHCND:USW00023234 | 2024-11-01 to 2024-12-01
#    → Fetching GHCND:USW00023234 | 2024-12-01 to 2025-01-01
#    ✅ Completed SFO: 3741 rows
#
# 📡 Fetching weather for BOS (GHCND:USW00014739)
#    → Fetching GHCND:USW00014739 | 2015-01-01 to 2015-02-01
#    → Fetching GHCND:USW00014739 | 2015-02-01 to 2015-03-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00014739 | 2015-03-01 to 2015-04-01
#    → Fetching GHCND:USW00014739 | 2015-04-01 to 2015-05-01
#    → Fetching GHCND:USW00014739 | 2015-05-01 to 2015-06-01
#    → Fetching GHCND:USW00014739 | 2015-06-01 to 2015-07-01
#    → Fetching GHCND:USW00014739 | 2015-07-01 to 2015-08-01
#    → Fetching GHCND:USW00014739 | 2015-08-01 to 2015-09-01
#    → Fetching GHCND:USW00014739 | 2015-09-01 to 2015-10-01
#    → Fetching GHCND:USW00014739 | 2015-10-01 to 2015-11-01
#    → Fetching GHCND:USW00014739 | 2015-11-01 to 2015-12-01
#    → Fetching GHCND:USW00014739 | 2015-12-01 to 2016-01-01
#    → Fetching GHCND:USW00014739 | 2016-01-01 to 2016-02-01
#    → Fetching GHCND:USW00014739 | 2016-02-01 to 2016-03-01
#    → Fetching GHCND:USW00014739 | 2016-03-01 to 2016-04-01
#    → Fetching GHCND:USW00014739 | 2016-04-01 to 2016-05-01
#    → Fetching GHCND:USW00014739 | 2016-05-01 to 2016-06-01
#    → Fetching GHCND:USW00014739 | 2016-06-01 to 2016-07-01
#    → Fetching GHCND:USW00014739 | 2016-07-01 to 2016-08-01
#    → Fetching GHCND:USW00014739 | 2016-08-01 to 2016-09-01
#    → Fetching GHCND:USW00014739 | 2016-09-01 to 2016-10-01
#    → Fetching GHCND:USW00014739 | 2016-10-01 to 2016-11-01
#    → Fetching GHCND:USW00014739 | 2016-11-01 to 2016-12-01
#    → Fetching GHCND:USW00014739 | 2016-12-01 to 2017-01-01
#    → Fetching GHCND:USW00014739 | 2017-01-01 to 2017-02-01
#    → Fetching GHCND:USW00014739 | 2017-02-01 to 2017-03-01
#    → Fetching GHCND:USW00014739 | 2017-03-01 to 2017-04-01
#    → Fetching GHCND:USW00014739 | 2017-04-01 to 2017-05-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00014739 | 2017-05-01 to 2017-06-01
#    → Fetching GHCND:USW00014739 | 2017-06-01 to 2017-07-01
#    → Fetching GHCND:USW00014739 | 2017-07-01 to 2017-08-01
#    → Fetching GHCND:USW00014739 | 2017-08-01 to 2017-09-01
#    → Fetching GHCND:USW00014739 | 2017-09-01 to 2017-10-01
#    → Fetching GHCND:USW00014739 | 2017-10-01 to 2017-11-01
#    → Fetching GHCND:USW00014739 | 2017-11-01 to 2017-12-01
#    → Fetching GHCND:USW00014739 | 2017-12-01 to 2018-01-01
#    → Fetching GHCND:USW00014739 | 2018-01-01 to 2018-02-01
#    → Fetching GHCND:USW00014739 | 2018-02-01 to 2018-03-01
#    → Fetching GHCND:USW00014739 | 2018-03-01 to 2018-04-01
#    → Fetching GHCND:USW00014739 | 2018-04-01 to 2018-05-01
#    → Fetching GHCND:USW00014739 | 2018-05-01 to 2018-06-01
#    → Fetching GHCND:USW00014739 | 2018-06-01 to 2018-07-01
#    → Fetching GHCND:USW00014739 | 2018-07-01 to 2018-08-01
#    → Fetching GHCND:USW00014739 | 2018-08-01 to 2018-09-01
#    → Fetching GHCND:USW00014739 | 2018-09-01 to 2018-10-01
#    → Fetching GHCND:USW00014739 | 2018-10-01 to 2018-11-01
#    → Fetching GHCND:USW00014739 | 2018-11-01 to 2018-12-01
#    → Fetching GHCND:USW00014739 | 2018-12-01 to 2019-01-01
#    → Fetching GHCND:USW00014739 | 2019-01-01 to 2019-02-01
#    → Fetching GHCND:USW00014739 | 2019-02-01 to 2019-03-01
#    → Fetching GHCND:USW00014739 | 2019-03-01 to 2019-04-01
#    → Fetching GHCND:USW00014739 | 2019-04-01 to 2019-05-01
#    → Fetching GHCND:USW00014739 | 2019-05-01 to 2019-06-01
#    → Fetching GHCND:USW00014739 | 2019-06-01 to 2019-07-01
#    → Fetching GHCND:USW00014739 | 2019-07-01 to 2019-08-01
#    → Fetching GHCND:USW00014739 | 2019-08-01 to 2019-09-01
#    → Fetching GHCND:USW00014739 | 2019-09-01 to 2019-10-01
#    → Fetching GHCND:USW00014739 | 2019-10-01 to 2019-11-01
#    → Fetching GHCND:USW00014739 | 2019-11-01 to 2019-12-01
#    → Fetching GHCND:USW00014739 | 2019-12-01 to 2020-01-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00014739 | 2020-01-01 to 2020-02-01
#    → Fetching GHCND:USW00014739 | 2020-02-01 to 2020-03-01
#    → Fetching GHCND:USW00014739 | 2020-03-01 to 2020-04-01
#    → Fetching GHCND:USW00014739 | 2020-04-01 to 2020-05-01
#    → Fetching GHCND:USW00014739 | 2020-05-01 to 2020-06-01
#    → Fetching GHCND:USW00014739 | 2020-06-01 to 2020-07-01
#    → Fetching GHCND:USW00014739 | 2020-07-01 to 2020-08-01
#    → Fetching GHCND:USW00014739 | 2020-08-01 to 2020-09-01
#    → Fetching GHCND:USW00014739 | 2020-09-01 to 2020-10-01
#    → Fetching GHCND:USW00014739 | 2020-10-01 to 2020-11-01
#    → Fetching GHCND:USW00014739 | 2020-11-01 to 2020-12-01
#    → Fetching GHCND:USW00014739 | 2020-12-01 to 2021-01-01
#    → Fetching GHCND:USW00014739 | 2021-01-01 to 2021-02-01
#    → Fetching GHCND:USW00014739 | 2021-02-01 to 2021-03-01
#    → Fetching GHCND:USW00014739 | 2021-03-01 to 2021-04-01
#    → Fetching GHCND:USW00014739 | 2021-04-01 to 2021-05-01
#    → Fetching GHCND:USW00014739 | 2021-05-01 to 2021-06-01
#    → Fetching GHCND:USW00014739 | 2021-06-01 to 2021-07-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00014739 | 2021-07-01 to 2021-08-01
#    → Fetching GHCND:USW00014739 | 2021-08-01 to 2021-09-01
#    → Fetching GHCND:USW00014739 | 2021-09-01 to 2021-10-01
#    → Fetching GHCND:USW00014739 | 2021-10-01 to 2021-11-01
#    → Fetching GHCND:USW00014739 | 2021-11-01 to 2021-12-01
#    → Fetching GHCND:USW00014739 | 2021-12-01 to 2022-01-01
#    → Fetching GHCND:USW00014739 | 2022-01-01 to 2022-02-01
#    → Fetching GHCND:USW00014739 | 2022-02-01 to 2022-03-01
#    → Fetching GHCND:USW00014739 | 2022-03-01 to 2022-04-01
#    → Fetching GHCND:USW00014739 | 2022-04-01 to 2022-05-01
#    → Fetching GHCND:USW00014739 | 2022-05-01 to 2022-06-01
#    → Fetching GHCND:USW00014739 | 2022-06-01 to 2022-07-01
#    → Fetching GHCND:USW00014739 | 2022-07-01 to 2022-08-01
#    → Fetching GHCND:USW00014739 | 2022-08-01 to 2022-09-01
#    → Fetching GHCND:USW00014739 | 2022-09-01 to 2022-10-01
#    → Fetching GHCND:USW00014739 | 2022-10-01 to 2022-11-01
#    → Fetching GHCND:USW00014739 | 2022-11-01 to 2022-12-01
#    → Fetching GHCND:USW00014739 | 2022-12-01 to 2023-01-01
#    → Fetching GHCND:USW00014739 | 2023-01-01 to 2023-02-01
#    → Fetching GHCND:USW00014739 | 2023-02-01 to 2023-03-01
#    → Fetching GHCND:USW00014739 | 2023-03-01 to 2023-04-01
#    → Fetching GHCND:USW00014739 | 2023-04-01 to 2023-05-01
#    → Fetching GHCND:USW00014739 | 2023-05-01 to 2023-06-01
#    → Fetching GHCND:USW00014739 | 2023-06-01 to 2023-07-01
#    → Fetching GHCND:USW00014739 | 2023-07-01 to 2023-08-01
#    → Fetching GHCND:USW00014739 | 2023-08-01 to 2023-09-01
#    → Fetching GHCND:USW00014739 | 2023-09-01 to 2023-10-01
#    → Fetching GHCND:USW00014739 | 2023-10-01 to 2023-11-01
#    → Fetching GHCND:USW00014739 | 2023-11-01 to 2023-12-01
#    → Fetching GHCND:USW00014739 | 2023-12-01 to 2024-01-01
#    → Fetching GHCND:USW00014739 | 2024-01-01 to 2024-02-01
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
#
#    → Fetching GHCND:USW00014739 | 2024-02-01 to 2024-03-01
#    → Fetching GHCND:USW00014739 | 2024-03-01 to 2024-04-01
#    → Fetching GHCND:USW00014739 | 2024-04-01 to 2024-05-01
#    → Fetching GHCND:USW00014739 | 2024-05-01 to 2024-06-01
#    → Fetching GHCND:USW00014739 | 2024-06-01 to 2024-07-01
#    → Fetching GHCND:USW00014739 | 2024-07-01 to 2024-08-01
#    → Fetching GHCND:USW00014739 | 2024-08-01 to 2024-09-01
#    → Fetching GHCND:USW00014739 | 2024-09-01 to 2024-10-01
#    → Fetching GHCND:USW00014739 | 2024-10-01 to 2024-11-01
#    → Fetching GHCND:USW00014739 | 2024-11-01 to 2024-12-01
#    → Fetching GHCND:USW00014739 | 2024-12-01 to 2025-01-01
#    ✅ Completed BOS: 3678 rows

# %%
df_weather_all = pd.concat(all_weather, ignore_index=True)
print("Total rows:", df_weather_all.shape)
df_weather_all.head()
# Out:
# Total rows: (55684, 35)
# datatype       date   ADPT     ASLP    ASTP   AWBT  AWND  PRCP  RHAV  RHMN  \
# 0        2015-01-01  -17.0  10271.0  9888.0   33.0   4.5  0.07  58.0  28.0
# 1        2015-01-02   61.0  10257.0  9878.0   72.0   3.8  0.95  88.0  76.0
# 2        2015-01-03  106.0  10220.0  9854.0  106.0   8.5  0.16  95.0  86.0
# 3        2015-01-04  106.0  10203.0  9821.0  122.0  11.4  1.64  80.0  47.0
# 4        2015-01-05  -33.0  10312.0  9925.0   17.0  12.1  0.00  55.0  32.0
#
# datatype   RHMX  ...  PSUN  TSUN  PGTM  WT05  airport         station_id  \
# 0          79.0  ...   NaN   NaN   NaN   NaN      ATL  GHCND:USW00013874
# 1          93.0  ...   NaN   NaN   NaN   NaN      ATL  GHCND:USW00013874
# 2         100.0  ...   NaN   NaN   NaN   NaN      ATL  GHCND:USW00013874
# 3          96.0  ...   NaN   NaN   NaN   NaN      ATL  GHCND:USW00013874
# 4          74.0  ...   NaN   NaN   NaN   NaN      ATL  GHCND:USW00013874
#
# datatype  WT07  WT09  WESD  WT10
# 0          NaN   NaN   NaN   NaN
# 1          NaN   NaN   NaN   NaN
# 2          NaN   NaN   NaN   NaN
# 3          NaN   NaN   NaN   NaN
# 4          NaN   NaN   NaN   NaN
#
# [5 rows x 35 columns]

# %%
df_weather_all.to_csv("noaa_weather_15airports_10years.csv", index=False)

# %%
#df_weather = fetch_noaa_weather("GHCND:USW00094728", "2024-01-01", "2025-01-01", NOAA_TOKEN)
# Out:
# Error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>

# %%
print(df_weather_all.head())
print(df_weather_all.info())
# Out:
# datatype       date   ADPT     ASLP    ASTP   AWBT  AWND  PRCP  RHAV  RHMN  \
# 0        2015-01-01  -17.0  10271.0  9888.0   33.0   4.5  0.07  58.0  28.0
# 1        2015-01-02   61.0  10257.0  9878.0   72.0   3.8  0.95  88.0  76.0
# 2        2015-01-03  106.0  10220.0  9854.0  106.0   8.5  0.16  95.0  86.0
# 3        2015-01-04  106.0  10203.0  9821.0  122.0  11.4  1.64  80.0  47.0
# 4        2015-01-05  -33.0  10312.0  9925.0   17.0  12.1  0.00  55.0  32.0
#
# datatype   RHMX  ...  PSUN  TSUN  PGTM  WT05  airport         station_id  \
# 0          79.0  ...   NaN   NaN   NaN   NaN      ATL  GHCND:USW00013874
# 1          93.0  ...   NaN   NaN   NaN   NaN      ATL  GHCND:USW00013874
# 2         100.0  ...   NaN   NaN   NaN   NaN      ATL  GHCND:USW00013874
# 3          96.0  ...   NaN   NaN   NaN   NaN      ATL  GHCND:USW00013874
# 4          74.0  ...   NaN   NaN   NaN   NaN      ATL  GHCND:USW00013874
#
# datatype  WT07  WT09  WESD  WT10
# 0          NaN   NaN   NaN   NaN
# 1          NaN   NaN   NaN   NaN
# 2          NaN   NaN   NaN   NaN
# 3          NaN   NaN   NaN   NaN
# 4          NaN   NaN   NaN   NaN
#
# [5 rows x 35 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55684 entries, 0 to 55683
# Data columns (total 35 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        55684 non-null  datetime64[ns]
#  1   ADPT        54724 non-null  float64
#  2   ASLP        54662 non-null  float64
#  3   ASTP        54662 non-null  float64
#  4   AWBT        54724 non-null  float64
#  5   AWND        55460 non-null  float64
#  6   PRCP        55621 non-null  float64
#  7   RHAV        54804 non-null  float64
#  8   RHMN        54804 non-null  float64
#  9   RHMX        54804 non-null  float64
#  10  SNOW        41451 non-null  float64
#  11  SNWD        37941 non-null  float64
#  12  TAVG        51861 non-null  float64
#  13  TMAX        55603 non-null  float64
#  14  TMIN        55602 non-null  float64
#  15  WDF2        55565 non-null  float64
#  16  WDF5        55337 non-null  float64
#  17  WSF2        55569 non-null  float64
#  18  WSF5        55342 non-null  float64
#  19  WT01        17075 non-null  float64
#  20  WT02        1857 non-null   float64
#  21  WT03        6443 non-null   float64
#  22  WT08        7869 non-null   float64
#  23  WT04        291 non-null    float64
#  24  WT06        240 non-null    float64
#  25  PSUN        790 non-null    float64
#  26  TSUN        905 non-null    float64
#  27  PGTM        1154 non-null   float64
#  28  WT05        124 non-null    float64
#  29  airport     55684 non-null  object
#  30  station_id  55684 non-null  object
#  31  WT07        150 non-null    float64
#  32  WT09        115 non-null    float64
#  33  WESD        2 non-null      float64
#  34  WT10        13 non-null     float64
# dtypes: datetime64[ns](1), float64(32), object(2)
# memory usage: 14.9+ MB
# None

# %%
test = fetch_station_monthly(
    station_id=airport_to_station["ATL"],
    start_date="2015-01-01",
    end_date="2015-02-01",
    token=NOAA_TOKEN
)

print(test.shape)
test.head()
# Out:
#    → Fetching GHCND:USW00013874 | 2015-01-01 to 2015-02-01
# (32, 23)
# datatype       date   ADPT     ASLP    ASTP   AWBT  AWND  PRCP  RHAV  RHMN  \
# 0        2015-01-01  -17.0  10271.0  9888.0   33.0   4.5  0.07  58.0  28.0
# 1        2015-01-02   61.0  10257.0  9878.0   72.0   3.8  0.95  88.0  76.0
# 2        2015-01-03  106.0  10220.0  9854.0  106.0   8.5  0.16  95.0  86.0
# 3        2015-01-04  106.0  10203.0  9821.0  122.0  11.4  1.64  80.0  47.0
# 4        2015-01-05  -33.0  10312.0  9925.0   17.0  12.1  0.00  55.0  32.0
#
# datatype   RHMX  ...  TMAX  TMIN   WDF2   WDF5  WSF2  WSF5  WT01  WT02  WT03  \
# 0          79.0  ...  58.0  32.0  340.0  330.0  10.1  16.1   NaN   NaN   NaN
# 1          93.0  ...  49.0  43.0   70.0   40.0  13.0  16.1   1.0   NaN   NaN
# 2         100.0  ...  62.0  48.0  110.0  110.0  14.1  18.1   1.0   1.0   NaN
# 3          96.0  ...  66.0  44.0  310.0  300.0  23.0  33.1   1.0   NaN   1.0
# 4          74.0  ...  48.0  34.0  320.0  320.0  25.9  33.1   NaN   NaN   NaN
#
# datatype  WT08
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 23 columns]

# %%
import pandas as pd

# Make sure dfweatherall is already defined as your DataFrame with weather data

# Select only numeric columns for correlation (drop date, airport, stationid)
numeric_cols = df_weather_all.drop(columns=['date', 'airport', 'stationid'], errors='ignore').select_dtypes(include=['number']).columns

# Calculate the correlation matrix
corr_matrix = df_weather_all[numeric_cols].corr()

# Save the correlation matrix as a CSV file for sharing or Tableau upload
corr_matrix.to_csv("weather_correlation_matrix.csv")

print("Correlation matrix saved as weather_correlation_matrix.csv")
# Out:
# Correlation matrix saved as weather_correlation_matrix.csv
